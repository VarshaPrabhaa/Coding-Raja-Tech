# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_df = pd.read_csv('Movie_Titles.csv',encoding='unicode_escape')

# %%
movie_df
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   item_id  1682 non-null   int64
#  1   title    1682 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 26.4+ KB

# %%
movie_df.isna().sum()
# Out:
# item_id    0
# title      0
# dtype: int64

# %%
movie_df.duplicated().sum()
# Out:
# 0

# %%
user_df = pd.read_csv('u.data',sep='\t',names=['user_id','item_id','rating','timestamp'])

# %%
user_df
# Out:
#        user_id  item_id  rating  timestamp
# 0          196      242       3  881250949
# 1          186      302       3  891717742
# 2           22      377       1  878887116
# 3          244       51       2  880606923
# 4          166      346       1  886397596
# ...        ...      ...     ...        ...
# 99995      880      476       3  880175444
# 99996      716      204       5  879795543
# 99997      276     1090       1  874795795
# 99998       13      225       2  882399156
# 99999       12      203       3  879959583
#
# [100000 rows x 4 columns]

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    100000 non-null  int64
#  1   item_id    100000 non-null  int64
#  2   rating     100000 non-null  int64
#  3   timestamp  100000 non-null  int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %%
user_df.describe()
# Out:
#             user_id        item_id         rating     timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08

# %%
user_df.isna().sum()
# Out:
# user_id      0
# item_id      0
# rating       0
# timestamp    0
# dtype: int64

# %%
user_df.duplicated().sum()
# Out:
# 0

# %%
df = user_df.merge(movie_df,on='item_id' )

# %%
df
# Out:
#        user_id  item_id  rating  timestamp  \
# 0          196      242       3  881250949
# 1           63      242       3  875747190
# 2          226      242       5  883888671
# 3          154      242       3  879138235
# 4          306      242       5  876503793
# ...        ...      ...     ...        ...
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 0                                           Kolya (1996)
# 1                                           Kolya (1996)
# 2                                           Kolya (1996)
# 3                                           Kolya (1996)
# 4                                           Kolya (1996)
# ...                                                  ...
# ...

# %%
df.describe()
# Out:
#             user_id        item_id         rating     timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08

# %%
#average rating for each movie

# %%
rating = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
rating['Count'] = df.groupby('title')['rating'].count()

# %%
rating.sort_values(by='Count',ascending=False)
# Out:
#                                                 rating  Count
# title
# Star Wars (1977)                              4.358491    583
# Contact (1997)                                3.803536    509
# Fargo (1996)                                  4.155512    508
# Return of the Jedi (1983)                     4.007890    507
# Liar Liar (1997)                              3.156701    485
# ...                                                ...    ...
# Shadow of Angels (Schatten der Engel) (1976)  1.000000      1
# Mat' i syn (1997)                             1.000000      1
# Butterfly Kiss (1995)                         1.000000      1
# Marlene Dietrich: Shadow and Light (1996)     5.000000      1
# Touki Bouki (Journey of the Hyena) (1973)     1.000000      1
#
# [1664 rows x 2 columns]

# %%
uii = df.pivot_table(index='user_id',columns='title',values='rating')

# %%
uii
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
uii.corr()
# Out:
# title                                  'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                    1.0
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                       -1.0
# 12 Angry Men (1957)                                         -0.5
# 187 (1997)                                                  -0.5
# ...                                                          ...
# Young Guns (1988)                                            NaN
# Young Guns II (1990)                                         NaN
# Young Poisoner's Handbook, The (1995)                        NaN
# Zeus and Roxanne (1997)                                      NaN
# unknown                                                      NaN
#
# title                                  1-900 (1994)  101 Dalmatians (1996)  \
# title
# 'Til There Was You (1997)                       NaN          -1.000000e+00
# ...

# %%
angry_rating=uii['12 Angry Men (1957)']
angry_rating
# Out:
# user_id
# 1      5.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
#       ...
# 939    NaN
# 940    NaN
# 941    NaN
# 942    NaN
# 943    NaN
# Name: 12 Angry Men (1957), Length: 943, dtype: float64

# %%
corr_angry=uii.corrwith(angry_rating)
# Out:
# C:\Users\Anaconda\Lib\site-packages\numpy\lib\function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\Anaconda\Lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)

# %%
corr_angry_df=pd.DataFrame(corr_angry,columns=['correlation'])

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import KNNBasic

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id', 'title', 'rating']], reader)

trainset, testset = train_test_split(data, test_size=0.2)

algo = KNNBasic(sim_options={'user_based': False})
algo.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
from surprise import accuracy

predictions = algo.test(testset)

accuracy.rmse(predictions)
# Out:
# RMSE: 0.9707
# 0.9706809444062161

# %%
predictions
# Out:
# [Prediction(uid=380, iid='Victor/Victoria (1982)', r_ui=2.0, est=3.160042481012868, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=498, iid='Sabrina (1954)', r_ui=2.0, est=3.2117746471067345, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=301, iid='Fargo (1996)', r_ui=5.0, est=3.79866966492326, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=189, iid='Bound (1996)', r_ui=3.0, est=4.1052177679073125, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=328, iid='Red Corner (1997)', r_ui=4.0, est=3.4757653216733253, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=311, iid='Lawrence of Arabia (1962)', r_ui=4.0, est=4.179784600280118, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=343, iid='Godfather: Part II, The (1974)', r_ui=4.0, est=4.509447255831603, details={'actual_k': 40, 'was_impossible': False}),
# ...

# %%
def get_top_n_recommendations(predictions, n=10):
    top_n = {}
    for uid, iid, true_r, est, _ in predictions:
        if uid not in top_n:
            top_n[uid] = []
        top_n[uid].append((iid, est))

    # Sort the predictions for each user and get top-N recommendations
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
import pickle

# %%
file = open('movie_recom.pkl','wb')
pickle.dump(algo,file)
